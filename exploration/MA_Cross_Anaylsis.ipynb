# %%
import pandas as pd
from plotting import CandlePlot
from datetime import date
pd.set_option("display.max_columns", None)

# %%
date = date.today()
df_ma_res = pd.read_pickle(f"../data/ma_result_{date}.pkl")
df_ma_trades = pd.read_pickle(f"../data/ma_trades_{date}.pkl")

# %%
df_ma_trades.head()
df_ma_trades.shape
# Out:
# (14091, 32)

# %%
df_ma_res.granularity.unique()
# Out:
# array(['H1', 'H4'], dtype=object)

# %%
df_ma_res_h1 = df_ma_res[df_ma_res.granularity == "H1"].copy()
df_ma_trades_h1 = df_ma_trades[df_ma_trades.granularity == "H1"].copy()

# %%
df_ma_trades_h1.shape
# Out:
# (7115, 32)

# %%
df_ma_res_h1.columns
# Out:
# Index(['pair', 'num_trades', 'total_gain', 'mean_gain', 'min_gain', 'max_gain',
#        'ma_l', 'ma_s', 'cross', 'granularity'],
#       dtype='object')

# %%
df_cross_summary = df_ma_res_h1[['pair', 'num_trades', 'total_gain','cross','granularity']].copy()

# %%
df_cross_summary
# Out:
#        pair  num_trades  total_gain         cross granularity
# 0   USD_JPY         207        1693   MA_10_MA_20          H1
# 1   USD_JPY         113        1354   MA_10_MA_40          H1
# 2   USD_JPY          97        -653   MA_20_MA_40          H1
# 3   USD_JPY         105         341   MA_30_MA_40          H1
# 4   USD_JPY          78        -640   MA_10_MA_80          H1
# ..      ...         ...         ...           ...         ...
# 91  AUD_JPY          39         -64  MA_40_MA_120          H1
# 92  AUD_JPY          69       -1340  MA_10_MA_150          H1
# 93  AUD_JPY          45        -549  MA_20_MA_150          H1
# 94  AUD_JPY          41        -356  MA_30_MA_150          H1
# 95  AUD_JPY          39         106  MA_40_MA_150          H1
#
# [96 rows x 5 columns]

# %%
df_cross_gr = df_cross_summary.groupby(by=["cross"], as_index=False).sum()
df_cross_gr.sort_values(by="total_gain", ascending=False, inplace=True)
# Out:
# /var/folders/l9/dfc4w4kd0_j2rc6pdj4hmlg00000gq/T/ipykernel_45251/71885012.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %%
df_cross_gr.head()
# Out:
#            cross  num_trades  total_gain
# 15   MA_40_MA_80         314        1852
# 12   MA_30_MA_80         332         526
# 11   MA_30_MA_40         729       -1050
# 13  MA_40_MA_120         230       -1573
# 4    MA_10_MA_80         455       -1604

# %%
total_pairs = len(df_ma_res_h1.pair.unique())

# %%
total_pairs
# Out:
# 6

# %%
temp = df_ma_res_h1[df_ma_res_h1.cross == "MA_10_MA_40"]

# %%
temp[temp.total_gain > 0].shape[0]
# Out:
# 2

# %%
for c in df_ma_res_h1.cross.unique():
    temp = df_ma_res_h1[df_ma_res_h1.cross == c]
    pg = temp[temp.total_gain > 0].shape[0]
    print(f"{c} pg: {pg} percent gain:{(pg / total_pairs) * 100:.0f}%")
# Out:
# MA_10_MA_20 pg: 3 percent gain:50%
# MA_10_MA_40 pg: 2 percent gain:33%
# MA_20_MA_40 pg: 1 percent gain:17%
# MA_30_MA_40 pg: 3 percent gain:50%
# MA_10_MA_80 pg: 2 percent gain:33%
# MA_20_MA_80 pg: 2 percent gain:33%
# MA_30_MA_80 pg: 4 percent gain:67%
# MA_40_MA_80 pg: 4 percent gain:67%
# MA_10_MA_120 pg: 1 percent gain:17%
# MA_20_MA_120 pg: 2 percent gain:33%
# MA_30_MA_120 pg: 2 percent gain:33%
# MA_40_MA_120 pg: 0 percent gain:0%
# MA_10_MA_150 pg: 1 percent gain:17%
# MA_20_MA_150 pg: 2 percent gain:33%
# MA_30_MA_150 pg: 0 percent gain:0%
# MA_40_MA_150 pg: 1 percent gain:17%

# %%
cross = "MA_40_MA_80"
df_MA_40_MA_80 = df_ma_res_h1[df_ma_res_h1.cross  == cross].copy()
df_MA_40_MA_80.sort_values(by="total_gain", ascending=False, inplace=True)

# %%
df_MA_40_MA_80
# Out:
#        pair  num_trades  total_gain  mean_gain  min_gain  max_gain   ma_l  \
# 87  AUD_JPY          51        1214         23      -152       495  MA_80
# 39  EUR_JPY          47        1019         21      -337       479  MA_80
# 7   USD_JPY          48         743         15      -245       642  MA_80
# 23  EUR_USD          57         156          2      -135       425  MA_80
# 55  EUR_AUD          52        -468         -9      -258       356  MA_80
# 71  AUD_USD          59        -812        -13      -205       210  MA_80
#
#      ma_s        cross granularity
# 87  MA_40  MA_40_MA_80          H1
# 39  MA_40  MA_40_MA_80          H1
# 7   MA_40  MA_40_MA_80          H1
# 23  MA_40  MA_40_MA_80          H1
# 55  MA_40  MA_40_MA_80          H1
# 71  MA_40  MA_40_MA_80          H1

# %%
df_gains = df_ma_trades_h1[(df_ma_trades_h1.cross == cross)&(df_ma_trades_h1.pair == "AUD_JPY")].copy()

# %%
df_gains.head()
# Out:
#                           time  volume   mid_o   mid_h   mid_l   mid_c  \
# 6664 2022-05-25 07:00:00+00:00   15044  90.367  90.517  90.134  90.182
# 6665 2022-05-27 05:00:00+00:00    3962  90.582  90.582  90.409  90.501
# 6666 2022-06-10 08:00:00+00:00   10340  95.199  95.494  95.181  95.456
# 6667 2022-06-16 08:00:00+00:00   16613  93.556  93.673  93.024  93.068
# 6668 2022-06-19 22:00:00+00:00    5510  93.628  93.886  93.618  93.862
#
#        bid_o   bid_h   bid_l   bid_c   ask_o   ask_h   ask_l   ask_c  \
# 6664  90.356  90.507  90.124  90.172  90.378  90.528  90.145  90.192
# 6665  90.573  90.573  90.399  90.492  90.591  90.591  90.419  90.510
# 6666  95.190  95.485  95.172  95.447  95.208  95.503  95.190  95.466
# 6667  93.547  93.664  93.015  93.059  93.564  93.682  93.033  93.077
# 6668  93.553  93.875  93.549  93.853  93.703  93.898  93.666  93.871
#
#           MA_40    MA_10      MA_80     MA_20     MA_150     MA_120  \
# 6664  90.279975  90.1852  90.285187  90.03525  90.261027  90.134525
# 6665  90.162075  90.3369  90.139038  90.21415  90.159573  90.242683
# 6666  95.799350  95.2693  95.819800  95.36730  95.080373  95.367617
# 6667  93.477025  93.9936  93.452275  93.79330  94.487340  94.030233
# 6668  93.424675  93.6183  93.438788  93.82675  93.789887  93.465050
#
#           MA_30     DELTA  DELTA_PREV  TRADE   DIFF   GAIN granularity  \
# 6664  90.124333 -0.005212    0.010537     -1  0.319  -31.9          H1
# 6665  90.168733  0.023038   -0.000225      1  4.955  495.5          H1
# 6666  95.567100 -0.020450    0.014862     -1 -2.388  238.8          H1
# 6667  93.599567  0.024750   -0.003287      1  0.794   79.4          H1
# 6668  93.678367 -0.014112    0.001037     -1 -0.388   38.8          H1
#
#          pair  GAIN_C   ma_l   ma_s        cross
# 6664  AUD_JPY   -31.9  MA_80  MA_40  MA_40_MA_80
# 6665  AUD_JPY   463.6  MA_80  MA_40  MA_40_MA_80
# 6666  AUD_JPY   702.4  MA_80  MA_40  MA_40_MA_80
# 6667  AUD_JPY   781.8  MA_80  MA_40  MA_40_MA_80
# 6668  AUD_JPY   820.6  MA_80  MA_40  MA_40_MA_80

# %%
cp = CandlePlot(df_gains, candles=False)
cp.show_plot(line_traces=['GAIN_C'])

# %%
for curr in df_MA_40_MA_80[df_MA_40_MA_80.total_gain > 0].pair.unique():
    temp_gain = df_ma_trades_h1[(df_ma_trades_h1.cross == cross)&(df_ma_trades_h1.pair == curr)].copy()
    print(curr, int(temp_gain.GAIN.sum()))
    cp = CandlePlot(temp_gain, candles=False)
    cp.show_plot(line_traces=['GAIN_C'])
# Out:
# AUD_JPY 1214
# EUR_JPY 1019
# USD_JPY 743
# EUR_USD 156
